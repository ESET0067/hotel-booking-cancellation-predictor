# %%
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from tensorflow import keras
from tensorflow.keras import layers

# --------------------------
# 1️⃣ Load the data
# --------------------------
hotel = pd.read_csv('hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

# Convert month names to numbers
X['arrival_date_month'] = X['arrival_date_month'].map({
    'January':1, 'February': 2, 'March':3,
    'April':4, 'May':5, 'June':6, 'July':7,
    'August':8, 'September':9, 'October':10,
    'November':11, 'December':12
})

# --------------------------
# 2️⃣ Define feature sets
# --------------------------
features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]

features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

# --------------------------
# 3️⃣ Define preprocessing pipelines
# --------------------------
transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"),
    StandardScaler()
)

transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore')
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat)
)

# --------------------------
# 4️⃣ Train/validation split (keep DataFrame here!)
# --------------------------
X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, stratify=y, train_size=0.75, random_state=42
)

# --------------------------
# 5️⃣ Fit the preprocessor FIRST (on DataFrame)
# --------------------------
preprocessor.fit(X_train)

# Save the fitted preprocessor
joblib.dump(preprocessor, "preprocessor.pkl")

# --------------------------
# 6️⃣ Transform the data
# --------------------------
X_train_processed = preprocessor.transform(X_train)
X_valid_processed = preprocessor.transform(X_valid)

# --------------------------
# 7️⃣ Build and train the model
# --------------------------
input_shape = [X_train_processed.shape[1]]

model = keras.Sequential([
    layers.InputLayer(input_shape=input_shape),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# --------------------------
# 8️⃣ Train with early stopping
# --------------------------
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True
)

history = model.fit(
    X_train_processed, y_train,
    validation_data=(X_valid_processed, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
    verbose=1
)

# --------------------------
# 9️⃣ Save model and print evaluation
# --------------------------
model.save("hotel_model.keras")

loss, accuracy = model.evaluate(X_valid_processed, y_valid)
print(f"Validation accuracy: {accuracy:.3f}")
print(f"Validation loss: {loss:.3f}")
# Out:
# Epoch 1/200
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7681 - loss: 0.4880 - val_accuracy: 0.7989 - val_loss: 0.4347
# Epoch 2/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8007 - loss: 0.4250 - val_accuracy: 0.8097 - val_loss: 0.4057
# Epoch 3/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8082 - loss: 0.4105 - val_accuracy: 0.8163 - val_loss: 0.3963
# Epoch 4/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8118 - loss: 0.4036 - val_accuracy: 0.8175 - val_loss: 0.3921
# Epoch 5/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8127 - loss: 0.3990 - val_accuracy: 0.8203 - val_loss: 0.3877
# Epoch 6/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8152 - loss: 0.3949 - val_accuracy: 0.8212 - val_loss: 0.3850
# Epoch 7/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8175 - loss: 0.3917 - val_accuracy: 0.8199 - val_loss: 0.3849
# Epoch 8/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8189 - loss: 0.3883 - val_accuracy: 0.8226 - val_loss: 0.3843
# Epoch 9/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8218 - loss: 0.3847 - val_accuracy: 0.8261 - val_loss: 0.3764
# Epoch 10/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8232 - loss: 0.3809 - val_accuracy: 0.8262 - val_loss: 0.3746
# Epoch 11/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8241 - loss: 0.3791 - val_accuracy: 0.8273 - val_loss: 0.3743
# Epoch 12/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8250 - loss: 0.3753 - val_accuracy: 0.8292 - val_loss: 0.3715
# Epoch 13/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8274 - loss: 0.3731 - val_accuracy: 0.8294 - val_loss: 0.3697
# Epoch 14/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8286 - loss: 0.3716 - val_accuracy: 0.8302 - val_loss: 0.3692
# Epoch 15/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8299 - loss: 0.3699 - val_accuracy: 0.8311 - val_loss: 0.3659
# Epoch 16/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8302 - loss: 0.3677 - val_accuracy: 0.8317 - val_loss: 0.3651
# Epoch 17/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8314 - loss: 0.3659 - val_accuracy: 0.8297 - val_loss: 0.3673
# Epoch 18/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8317 - loss: 0.3638 - val_accuracy: 0.8317 - val_loss: 0.3661
# Epoch 19/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8331 - loss: 0.3638 - val_accuracy: 0.8318 - val_loss: 0.3635
# Epoch 20/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8331 - loss: 0.3618 - val_accuracy: 0.8326 - val_loss: 0.3616
# Epoch 21/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8349 - loss: 0.3589 - val_accuracy: 0.8323 - val_loss: 0.3615
# Epoch 22/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8348 - loss: 0.3585 - val_accuracy: 0.8335 - val_loss: 0.3606
# Epoch 23/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8353 - loss: 0.3572 - val_accuracy: 0.8342 - val_loss: 0.3605
# Epoch 24/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8353 - loss: 0.3572 - val_accuracy: 0.8355 - val_loss: 0.3593
# Epoch 25/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8386 - loss: 0.3548 - val_accuracy: 0.8358 - val_loss: 0.3579
# Epoch 26/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8367 - loss: 0.3545 - val_accuracy: 0.8351 - val_loss: 0.3576
# Epoch 27/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.8370 - loss: 0.3524 - val_accuracy: 0.8341 - val_loss: 0.3570
# Epoch 28/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8369 - loss: 0.3539 - val_accuracy: 0.8361 - val_loss: 0.3569
# Epoch 29/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8383 - loss: 0.3514 - val_accuracy: 0.8349 - val_loss: 0.3570
# Epoch 30/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8386 - loss: 0.3499 - val_accuracy: 0.8362 - val_loss: 0.3566
# Epoch 31/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8398 - loss: 0.3498 - val_accuracy: 0.8357 - val_loss: 0.3549
# Epoch 32/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8394 - loss: 0.3481 - val_accuracy: 0.8373 - val_loss: 0.3530
# Epoch 33/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8391 - loss: 0.3477 - val_accuracy: 0.8374 - val_loss: 0.3546
# Epoch 34/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8400 - loss: 0.3472 - val_accuracy: 0.8352 - val_loss: 0.3552
# Epoch 35/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8412 - loss: 0.3457 - val_accuracy: 0.8373 - val_loss: 0.3539
# Epoch 36/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8426 - loss: 0.3435 - val_accuracy: 0.8368 - val_loss: 0.3551
# Epoch 37/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8411 - loss: 0.3453 - val_accuracy: 0.8368 - val_loss: 0.3537
# 933/933 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8373 - loss: 0.3530
# Validation accuracy: 0.837
# Validation loss: 0.353
